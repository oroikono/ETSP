# %%
from datasets import load_dataset

from huggingface_hub import login

# %% [markdown]
# # Load dataset from huggingface

# %%
# READ Token : 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

login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid.
# Your token has been saved to /Users/hyeongkyunkim/.huggingface/token
# Login successful

# %%
# dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-base-bar", split="test")
# dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-base-line", split="test")

# dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-bar", split="test")
# dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-line", split="test")

# dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-noaxislabel-bar", split="test")
# dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-noaxislabel-line", split="test")

# dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-bar", split="test")
# dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-line", split="test")

# dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-multi-base-bar", split="test")
# dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-multi-base-line", split="test")

dataset1 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-multi-subplot-bar", split="test")
dataset2 = load_dataset("hk-kaden-kim/uzh-hs23-etsp-eval-multi-subplot-line", split="test")
# Out:
# ...
# Using custom data configuration hk-kaden-kim--uzh-hs23-etsp-eval-multi-subplot-bar-ec641e1e33814025
# ...
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /Users/hyeongkyunkim/.cache/huggingface/datasets/hk-kaden-kim___parquet/hk-kaden-kim--uzh-hs23-etsp-eval-multi-subplot-bar-ec641e1e33814025/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
# ...
# Using custom data configuration hk-kaden-kim--uzh-hs23-etsp-eval-multi-subplot-line-f37fea49d67e9ae1
# ...
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /Users/hyeongkyunkim/.cache/huggingface/datasets/hk-kaden-kim___parquet/hk-kaden-kim--uzh-hs23-etsp-eval-multi-subplot-line-f37fea49d67e9ae1/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
print(dataset1[0]["caption"])
dataset1[0]["image"]
# Out:
#  This statistic presents the most important attributes of facial skin care products to male and female consumers in the United Kingdom, according to a survey conducted in March 2013. Skin moisturising and hydrating attributes were considered the most important attributes for both genders, with 73 percent of women stating this as important.  The anti-ageing moisturiser market takes up the largest proportion of the facial skin care market with a share of 41.6 percent in 2013.  Over The Counter skin treatments, or OTC's have seen a significant decline in sales value since 2009, with a decline of nearly 210 million British pounds. This could be due to harder regulation in European countries, or by the fact that consumers are more interested in organic and natural skin products. A total of 54 percent of people claimed that they want no chemical ingredients in their personal care products and 30 percent stated that they want non animal tested products.
# ...

# %%
print(dataset2[0]["caption"])
dataset2[0]["image"]
# Out:
#  In the week ending December 4, 2020 there were over 12.3 thousand deaths registered in England and Wales, which was approximately 1.6 thousand more than the average for this week between 2014 and 2019. The sharp increase in deaths in April 2020 can be attributed to the excess deaths which were caused by the Coronavirus pandemic.
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1002x480>

# %% [markdown]
# # Upload dataset into huggingface

# %%
# login(token="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")

# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_base/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-base-bar")
# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_base/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-base-line")

# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_axis_label/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-noaxislabel-bar")
# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_axis_label/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-noaxislabel-line")

# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_grid/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-nogrid-bar")
# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_grid/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-nogrid-line")

# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_title/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-bar")
# dataset = load_dataset("imagefolder", data_dir="./singleColumn/eval_no_title/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-single-notitle-line")

# dataset = load_dataset("imagefolder", data_dir="./multiColumn/eval_multi_base/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-multi-base-bar")
# dataset = load_dataset("imagefolder", data_dir="./multiColumn/eval_multi_base/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-multi-base-line")

# dataset = load_dataset("imagefolder", data_dir="./multiColumn/eval_multi_subplot/bar", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-multi-subplot-bar")
# dataset = load_dataset("imagefolder", data_dir="./multiColumn/eval_multi_subplot/line", split="test")
# dataset.push_to_hub("hk-kaden-kim/uzh-hs23-etsp-eval-multi-subplot-line")
